# %%
import os
import pathlib
import time

# %%
p = pathlib.Path('weights/dgmr_oneshot')

# %%
while True:
    files = os.listdir(p)
    for f in files:
        if 'batch' in f:
            path = p / f
            print(f'deleting {path.name}')
            os.remove(path)
    print('sleeping')
    time.sleep(20*60)
# Out:
# deleting dgmr_epochs=2_batch=1027_loss=0.2606.pt
# deleting dgmr_epochs=2_batch=2055_loss=0.2617.pt
# sleeping
# deleting dgmr_epochs=4_batch=1027_loss=0.2502.pt
# deleting dgmr_epochs=3_batch=2055_loss=0.2562.pt
# deleting dgmr_epochs=3_batch=1027_loss=0.2584.pt
# sleeping
# deleting dgmr_epochs=5_batch=1027_loss=0.2451.pt
# deleting dgmr_epochs=4_batch=2055_loss=0.249.pt
# sleeping
# deleting dgmr_epochs=5_batch=2055_loss=0.245.pt
# deleting dgmr_epochs=6_batch=1027_loss=0.2426.pt
# sleeping
# deleting dgmr_epochs=6_batch=2055_loss=0.2424.pt
# deleting dgmr_epochs=7_batch=1027_loss=0.24.pt
# sleeping
# deleting dgmr_epochs=7_batch=2055_loss=0.2397.pt
# deleting dgmr_epochs=8_batch=1027_loss=0.2372.pt
# sleeping
# deleting dgmr_epochs=9_batch=1027_loss=0.2363.pt
# deleting dgmr_epochs=8_batch=2055_loss=0.237.pt
# sleeping
# deleting dgmr_epochs=10_batch=1027_loss=0.2343.pt
# deleting dgmr_epochs=10_batch=2055_loss=0.2338.pt
# deleting dgmr_epochs=9_batch=2055_loss=0.2355.pt
# ...
