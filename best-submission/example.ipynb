# %% [markdown]
# # Climate Hack.AI 2022
#
# Thank you for participating in Climate Hack.AI 2022!
#
# Your hard work in helping to advance the state of the art in HRV satellite imagery nowcasting could be incredibly impactful in the broader fight against climate change. Within the UK electricty grid alone, your model could contribute to a reduction in carbon emissions of up to 100 kilotonnes a year.
#
# Happy model training!
#
# ## Prerequisites
#
# Before you begin, please ensure that you have the following packages installed.
#
# * `xarray` for representing n-dimensional labelled arrays
# * `zarr` for loading the Zarr dataset
# * `gcsfs` for loading from Google Cloud Storage:  used implicitly by xarray)
# * `dask` used under the hood by xarray to enable parallel processing of datasets too large to fit into RAM
# * `torch` (PyTorch) for training a model
# * `pytorch_msssim` to use a multi-scale structural similarity index measure-based loss function
# * `matplotlib` for plotting
#
# If you want to install them using `pip`, you can run the following command (replacing `python` with `python3` as appropriate):
#
# ```bash
# $ python -m pip install numpy matplotlib zarr xarray ipykernel gcsfs fsspec dask cartopy
# ```
#
# You will then need to install the appropriate PyTorch distribution for your system, the instructions for which may be found [here](https://pytorch.org/get-started/locally/).
#
# Otherwise, if you are familar with `conda`, you may want to run the following commands to set up a `conda` environment for Climate Hack.AI:
#
# ```bash
# $ conda create --name climatehack python=3.9 numpy matplotlib zarr xarray ipykernel gcsfs fsspec dask cartopy
# $ conda activate climatehack
# $ conda install pytorch torchvision torchaudio cpuonly -c pytorch
# $ conda install -c pvlib pvlib
# ```

# %% [markdown]
# ## Importing modules

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import xarray as xr
from numpy import float32
from torch.utils.data import DataLoader

from dataset import ClimateHackDataset
from loss import MS_SSIMLoss
from submission.model import Model

plt.rcParams["figure.figsize"] = (20, 12)

# %% [markdown]
# ## Loading the dataset
#
# The 108GB HRV ("high resolution visible") satellite imagery dataset may be loaded directly from Google Cloud Public Datasets using `xarray`, `zarr`, `gcsfs` and `dask`. Alternatively a local copy can be downloaded and loaded instead for better performance. The pixel values represent calibrated top-of-atmosphere bidirectional irradiance values mapped to the range `[0, 1023]`. Read more about the data on the [Google Cloud Platform](https://console.cloud.google.com/marketplace/product/bigquery-public-data/eumetsat-seviri-rss-hrv-uk).
#
# ### Loading the dataset from the cloud

# %%
SATELLITE_ZARR_PATH = "gs://public-datasets-eumetsat-solar-forecasting/satellite/EUMETSAT/SEVIRI_RSS/v3/eumetsat_seviri_hrv_uk.zarr"

dataset = xr.open_dataset(
    SATELLITE_ZARR_PATH, 
    engine="zarr",
    chunks="auto",  # Load the data as a Dask array
)

print(dataset)
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 26148, y: 891, x: 1843)
# Coordinates:
#   * time     (time) datetime64[ns] 2020-06-01T09:00:00 ... 2020-09-01T16:00:00
#   * x        (x) float32 2.8e+04 2.7e+04 2.6e+04 ... -1.813e+06 -1.814e+06
#     x_osgb   (y, x) float32 dask.array<chunksize=(891, 1843), meta=np.ndarray>
#   * y        (y) float32 4.198e+06 4.199e+06 4.2e+06 ... 5.087e+06 5.088e+06
#     y_osgb   (y, x) float32 dask.array<chunksize=(891, 1843), meta=np.ndarray>
# Data variables:
#     data     (time, y, x) int16 dask.array<chunksize=(40, 891, 1843), meta=np.ndarray>

# %% [markdown]
# ### Loading a local copy of the dataset
#
# Loading data from the cloud in this way can often be slow, so it is likely that you will want to download a local copy of the 104GiB dataset, at least in part.
#
# To do this, first install `gsutil` by following [these instructions](https://cloud.google.com/storage/docs/gsutil_install).
#
# Then, run the following command to start downloading the dataset into your current working directory:
#
# ```bash
# $ gsutil -m cp -rJn gs://public-datasets-eumetsat-solar-forecasting/satellite/EUMETSAT/SEVIRI_RSS/v3/eumetsat_seviri_hrv_uk.zarr .
# ```
#
# The `-n` no-clobber flag will skip previously downloaded files if the command is run multiple times, so you can download as much of the dataset as you want in stages.
#
# Then, change the `SATELLITE_ZARR_PATH` to point to the downloaded data on your computer.
#
# ```python
# SATELLITE_ZARR_PATH = "eumetsat_seviri_hrv_uk.zarr"
# ```

# %% [markdown]
# ## Visualising the data
#
# You may be curious what these 1841x891 "high resolution visible" satellite images actually look like!
#
# Here is an example:

# %%
dataset["data"].sel(time="2020-06-01 12:00").plot()

# %% [markdown]
# As part of your challenge, you are given twelve 128x128 images taken five minutes apart corresponding to some region inside the 1841x891 image above, e.g.

# %%
fig, ax = plt.subplots(1, 12, figsize=(15,3))

for i, d in enumerate(["2020-07-04 12:00", "2020-07-04 12:05", "2020-07-04 12:10", "2020-07-04 12:15", "2020-07-04 12:20", "2020-07-04 12:25", "2020-07-04 12:30", "2020-07-04 12:35", "2020-07-04 12:40", "2020-07-04 12:45", "2020-07-04 12:50", "2020-07-04 12:55"]):
    ax[i].imshow(dataset["data"].sel(time=d).isel(x=slice(128, 256), y=slice(128, 256)).to_numpy(), cmap='viridis')
    ax[i].get_xaxis().set_visible(False)
    ax[i].get_yaxis().set_visible(False)

fig.tight_layout()
fig.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# From these, your aim is to predict the next 24 images taken five minutes apart for the centre 64x64 region of the 128x128 area.

# %%
fig, (ax1, ax2) = plt.subplots(2, 12, figsize=(16,3))

for i, d in enumerate(["2020-07-04 13:00", "2020-07-04 13:05", "2020-07-04 13:10", "2020-07-04 13:15", "2020-07-04 13:20", "2020-07-04 13:25", "2020-07-04 13:30", "2020-07-04 13:35", "2020-07-04 13:40", "2020-07-04 13:45", "2020-07-04 13:50", "2020-07-04 13:55"]):
    ax1[i].imshow(dataset["data"].sel(time=d).isel(x=slice(160, 224), y=slice(160, 224)).to_numpy(), cmap='viridis')
    ax1[i].get_xaxis().set_visible(False)
    ax1[i].get_yaxis().set_visible(False)

for i, d in enumerate(["2020-07-04 14:00", "2020-07-04 14:05", "2020-07-04 14:10", "2020-07-04 14:15", "2020-07-04 14:20", "2020-07-04 14:25", "2020-07-04 14:30", "2020-07-04 14:35", "2020-07-04 14:40", "2020-07-04 14:45", "2020-07-04 14:50", "2020-07-04 14:55"]):
    ax2[i].imshow(dataset["data"].sel(time=d).isel(x=slice(160, 224), y=slice(160, 224)).to_numpy(), cmap='viridis')
    ax2[i].get_xaxis().set_visible(False)
    ax2[i].get_yaxis().set_visible(False)

fig.tight_layout()
fig.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# ## Creating a model
#
# ### Defining constants

# %%
BATCH_SIZE = 30
EPOCHS = 20

# %% [markdown]
# ### Instantiating the DataLoader
#
# Since the dataset is so large, we have provided a `ClimateHackDataset` class in `dataset.py` that selects a sliding window of twelve 128x128 images (taken five minutes apart, corresponding to an hour of data) for randomly sampled areas roughly over the mainland UK to use in training.
#
# You do not have to use this at all, if you don't want to. In fact, you are encouraged to customise it as you see fit to better suit your models!

# %%
# Increase crops_per_slice if you want to crop out multiple 128x128 areas from the same sliding window.
# To only train on a subset of the dataset, either select what you want and pass it into ClimateHackDataset,
# set start_date and end_date to Python datetime objects, or set day_limit > 0 to the number of days from the start to read.

ch_dataset = ClimateHackDataset(dataset, crops_per_slice=1, day_limit=7)
ch_dataloader = DataLoader(ch_dataset, batch_size=BATCH_SIZE)

# %% [markdown]
# ### Instantiating the model
#
# Any models you define need to be in the `submission` folder so that they can be evaluated on DOXA. By default, they are defined in `submission/model.py`, which is where this PyTorch model is defined.
#
# There are some huge improvements you can make to this basic model, so feel free to use this as a starting point and customise `submission/model.py` to your liking!

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Model().to(device)
optimiser = optim.Adam(model.parameters(), lr=1e-4)
criterion = MS_SSIMLoss(channels=24) # produces less blurry images than nn.MSELoss()

# %% [markdown]
# ### Training the model

# %%
losses = []
for epoch in range(EPOCHS):
    print(f"Epoch {epoch + 1}")
    running_loss = 0
    i = 0
    count = 0
    for batch_coordinates, batch_features, batch_targets in ch_dataloader:
        optimiser.zero_grad()
        batch_predictions = model(batch_features.to(device))

        batch_loss = criterion(batch_predictions.unsqueeze(dim=2), batch_targets.unsqueeze(dim=2).to(device))
        batch_loss.backward()

        optimiser.step()

        running_loss += batch_loss.item() * batch_predictions.shape[0]
        count += batch_predictions.shape[0]
        i += 1

        print(f"Completed batch {i} of epoch {epoch + 1} with loss {batch_loss.item()} -- processed {count} image sequences ({12 * count} images)")
    
    losses.append(running_loss / count)
    print(f"Loss for epoch {epoch + 1}/{EPOCHS}: {losses[-1]}")
# Out:
# Epoch 1
# Completed batch 1 of epoch 1 with loss 0.4786563515663147 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 1 with loss 0.9616462588310242 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 1 with loss 0.9386224746704102 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 1 with loss 0.9293803572654724 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 1 with loss 0.865760326385498 -- processed 128 image sequences (1536 images)
# Loss for epoch 1/20: 0.8294941084459424
# Epoch 2
# Completed batch 1 of epoch 2 with loss 0.6237041354179382 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 2 with loss 0.8033859133720398 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 2 with loss 0.843064546585083 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 2 with loss 0.7848513722419739 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 2 with loss 0.6928571462631226 -- processed 128 image sequences (1536 images)
# Loss for epoch 2/20: 0.7593205953016877
# Epoch 3
# Completed batch 1 of epoch 3 with loss 0.4773973822593689 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 3 with loss 0.6635233163833618 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 3 with loss 0.8102220296859741 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 3 with loss 0.6978895664215088 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 3 with loss 0.6709823608398438 -- processed 128 image sequences (1536 images)
# Loss for epoch 3/20: 0.6628033416345716
# Epoch 4
# Completed batch 1 of epoch 4 with loss 0.4771425127983093 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 4 with loss 0.6736469268798828 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 4 with loss 0.8078570365905762 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 4 with loss 0.6985094547271729 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 4 with loss 0.673654317855835 -- processed 128 image sequences (1536 images)
# Loss for epoch 4/20: 0.6648743161931634
# Epoch 5
# Completed batch 1 of epoch 5 with loss 0.47453129291534424 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 5 with loss 0.6564067006111145 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 5 with loss 0.8094109892845154 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 5 with loss 0.6976680755615234 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 5 with loss 0.6719127893447876 -- processed 128 image sequences (1536 images)
# Loss for epoch 5/20: 0.6602797973901033
# Epoch 6
# Completed batch 1 of epoch 6 with loss 0.4728623628616333 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 6 with loss 0.655249297618866 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 6 with loss 0.808599591255188 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 6 with loss 0.6965961456298828 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 6 with loss 0.6698837280273438 -- processed 128 image sequences (1536 images)
# Loss for epoch 6/20: 0.6590491542592645
# Epoch 7
# Completed batch 1 of epoch 7 with loss 0.47092145681381226 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 7 with loss 0.6539422273635864 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 7 with loss 0.8076142072677612 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 7 with loss 0.6954399347305298 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 7 with loss 0.6677441596984863 -- processed 128 image sequences (1536 images)
# Loss for epoch 7/20: 0.6576522504910827
# Epoch 8
# Completed batch 1 of epoch 8 with loss 0.46891337633132935 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 8 with loss 0.6525912880897522 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 8 with loss 0.8064937591552734 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 8 with loss 0.6942648887634277 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 8 with loss 0.6655764579772949 -- processed 128 image sequences (1536 images)
# Loss for epoch 8/20: 0.6561914924532175
# Epoch 9
# Completed batch 1 of epoch 9 with loss 0.46688443422317505 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 9 with loss 0.651246190071106 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 9 with loss 0.8054012060165405 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 9 with loss 0.6931028366088867 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 9 with loss 0.6633297204971313 -- processed 128 image sequences (1536 images)
# Loss for epoch 9/20: 0.6547318575903773
# Epoch 10
# Completed batch 1 of epoch 10 with loss 0.46547257900238037 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 10 with loss 0.649394690990448 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 10 with loss 0.8021183013916016 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 10 with loss 0.6958291530609131 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 10 with loss 0.6613612174987793 -- processed 128 image sequences (1536 images)
# Loss for epoch 10/20: 0.653713527135551
# Epoch 11
# Completed batch 1 of epoch 11 with loss 0.4632205367088318 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 11 with loss 0.6488113403320312 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 11 with loss 0.8053662776947021 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 11 with loss 0.6910227537155151 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 11 with loss 0.659485936164856 -- processed 128 image sequences (1536 images)
# Loss for epoch 11/20: 0.6525665214285254
# Epoch 12
# Completed batch 1 of epoch 12 with loss 0.46159684658050537 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 12 with loss 0.6476905345916748 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 12 with loss 0.8047209978103638 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 12 with loss 0.6900204420089722 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 12 with loss 0.6575586795806885 -- processed 128 image sequences (1536 images)
# Loss for epoch 12/20: 0.6514166723936796
# Epoch 13
# Completed batch 1 of epoch 13 with loss 0.4599663019180298 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 13 with loss 0.6465648412704468 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 13 with loss 0.8040725588798523 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 13 with loss 0.6890271902084351 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 13 with loss 0.6556434631347656 -- processed 128 image sequences (1536 images)
# Loss for epoch 13/20: 0.6502662068232894
# Epoch 14
# Completed batch 1 of epoch 14 with loss 0.45836544036865234 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 14 with loss 0.6454546451568604 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 14 with loss 0.803432822227478 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 14 with loss 0.688056230545044 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 14 with loss 0.6537578105926514 -- processed 128 image sequences (1536 images)
# Loss for epoch 14/20: 0.6491354424506426
# Epoch 15
# Completed batch 1 of epoch 15 with loss 0.4568154811859131 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 15 with loss 0.644371747970581 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 15 with loss 0.8028085231781006 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 15 with loss 0.6871157288551331 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 15 with loss 0.6519156694412231 -- processed 128 image sequences (1536 images)
# Loss for epoch 15/20: 0.6480364827439189
# Epoch 16
# Completed batch 1 of epoch 16 with loss 0.4553297162055969 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 16 with loss 0.6433241367340088 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 16 with loss 0.802203357219696 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 16 with loss 0.6862092018127441 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 16 with loss 0.6501240730285645 -- processed 128 image sequences (1536 images)
# Loss for epoch 16/20: 0.6469764448702335
# Epoch 17
# Completed batch 1 of epoch 17 with loss 0.45391297340393066 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 17 with loss 0.6423149108886719 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 17 with loss 0.801619291305542 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 17 with loss 0.6853379011154175 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 17 with loss 0.6483868360519409 -- processed 128 image sequences (1536 images)
# Loss for epoch 17/20: 0.6459581796079874
# Epoch 18
# Completed batch 1 of epoch 18 with loss 0.45256584882736206 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 18 with loss 0.6413445472717285 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 18 with loss 0.8010566234588623 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 18 with loss 0.6845020055770874 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 18 with loss 0.6467061042785645 -- processed 128 image sequences (1536 images)
# Loss for epoch 18/20: 0.6449821842834353
# Epoch 19
# Completed batch 1 of epoch 19 with loss 0.45128822326660156 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 19 with loss 0.6404138803482056 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 19 with loss 0.8005154728889465 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 19 with loss 0.6837012767791748 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 19 with loss 0.6450835466384888 -- processed 128 image sequences (1536 images)
# Loss for epoch 19/20: 0.6440487029030919
# Epoch 20
# Completed batch 1 of epoch 20 with loss 0.45007699728012085 -- processed 30 image sequences (360 images)
# Completed batch 2 of epoch 20 with loss 0.6395219564437866 -- processed 60 image sequences (720 images)
# Completed batch 3 of epoch 20 with loss 0.799994945526123 -- processed 90 image sequences (1080 images)
# Completed batch 4 of epoch 20 with loss 0.6829344034194946 -- processed 120 image sequences (1440 images)
# Completed batch 5 of epoch 20 with loss 0.6435186862945557 -- processed 128 image sequences (1536 images)
# Loss for epoch 20/20: 0.6431562388315797

# %% [markdown]
# ## Visualising the loss

# %%
plt.plot(range(EPOCHS), losses)
plt.xlabel("Epoch")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %% [markdown]
# ## Visualising its predictions
#
# Having trained the model, it is often useful to visualise some of its predictions to ensure it is producing a sensible output.

# %%
x = dataset["data"].sel(time=slice("2020-07-01 12:00", "2020-07-01 12:55")).isel(x=slice(128, 256), y=slice(128, 256)).to_numpy()
y = dataset["data"].sel(time=slice("2020-07-01 13:00", "2020-07-01 14:55")).isel(x=slice(160, 224), y=slice(160, 224)).to_numpy()
p = model(torch.from_numpy(x.astype(float32)).unsqueeze(dim=0)).detach().numpy()[0]

fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, 12, figsize=(20,8))

# plot the twelve 128x128 input images
for i, img in enumerate(x):
    ax1[i].imshow(img, cmap='viridis')
    ax1[i].get_xaxis().set_visible(False)
    ax1[i].get_yaxis().set_visible(False)

# plot twelve 64x64 true output images
for i, img in enumerate(y[:12]):
    ax2[i].imshow(img, cmap='viridis')
    ax2[i].get_xaxis().set_visible(False)
    ax2[i].get_yaxis().set_visible(False)

# plot twelve more 64x64 true output images
for i, img in enumerate(y[12:]):
    ax3[i].imshow(img, cmap='viridis')
    ax3[i].get_xaxis().set_visible(False)
    ax3[i].get_yaxis().set_visible(False)

# plot the twelve 64x64 predicted output images
for i, img in enumerate(p[:12]):
    ax4[i].imshow(img, cmap='viridis')
    ax4[i].get_xaxis().set_visible(False)
    ax4[i].get_yaxis().set_visible(False)

# plot twelve more 64x64 output images
for i, img in enumerate(p[12:]):
    ax5[i].imshow(img, cmap='viridis')
    ax5[i].get_xaxis().set_visible(False)
    ax5[i].get_yaxis().set_visible(False)

fig.tight_layout()
fig.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# ### Saving the model
#
# Having trained the model, it can now be saved in the `submission` folder so that it may be evaluated on [DOXA](https://climatehack.ai/compete).

# %%
torch.save(model.state_dict(), 'submission/model.pt')

# %% [markdown]
# ## Submitting your model to DOXA
#
# Well done -- you made it to the end!
#
# You are now ready to submit your model to DOXA!
#
# If you are not already logged in, run the following command:
#
# ```bash
# $ python doxa_cli.py user login
# ```
#
# Finally, to submit your model, upload the entire `submission` folder into which your model was saved using the following command:
#
# ```bash
# $ python doxa_cli.py agent upload climatehack ./submission
# ```
